# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import json
import pandas as pd
from config import api_key

# %%
stock = "GOOG"

# %%
url = f"https://www.quandl.com/api/v3/datasets/WIKI/{stock}.json?start_date=2016-10-01&end_date=2017-10-01&api_key={api_key}"

# %%
stock_response = requests.get(url).json()
#stock_json = stock_response.json()


# Get the temperature from the response
print(f"The Quandl API responded with: {stock_response}.")
# Out:
# The Quandl API responded with: {'dataset': {'id': 9775718, 'dataset_code': 'GOOG', 'database_code': 'WIKI', 'name': 'Alphabet Inc (GOOG) Prices, Dividends, Splits and Trading Volume', 'description': "End of day open, high, low, close and volume, dividends and splits, and split/dividend adjusted open, high, low close and volume for Google Inc. (GOOG). Ex-Dividend is non-zero on ex-dividend dates. Split Ratio is 1 on non-split dates. Adjusted prices are calculated per CRSP (www.crsp.com/products/documentation/crsp-calculations)\n\nThis data is in the public domain. You may copy, distribute, disseminate or include the data in other products for commercial and/or noncommercial purposes.\n\nThis data is part of Quandl's Wiki initiative to get financial data permanently into the public domain. Quandl relies on users like you to flag errors and provide data where data is wrong or missing. Get involved: connect@quandl.com\n", 'refreshed_at': '2018-03-27T21:46:11.178Z', 'newest_available_date
# ...

# %%
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "dataset": {
#         "collapse": null,
#         "column_index": null,
#         "column_names": [
#             "Date",
#             "Open",
#             "High",
#             "Low",
#             "Close",
#             "Volume",
#             "Ex-Dividend",
#             "Split Ratio",
#             "Adj. Open",
#             "Adj. High",
#             "Adj. Low",
#             "Adj. Close",
#             "Adj. Volume"
#         ],
#         "data": [
#             [
#                 "2017-09-29",
#                 952.0,
#                 959.7864,
#                 951.51,
#                 959.11,
#                 1533133.0,
#                 0.0,
#                 1.0,
#                 952.0,
#                 959.7864,
#                 951.51,
#                 959.11,
#                 1533133.0
#             ],
#             [
#                 "2017-09-28",
#                 941.36,
#                 950.69,
#                 940.55,
# ...

# %%
df = pd.DataFrame(response['dataset']['data'], columns = response['dataset']['column_names'])
df
# Out:
#            Date    Open      High     Low   Close     Volume  Ex-Dividend  \
# 0    2017-09-29  952.00  959.7864  951.51  959.11  1533133.0          0.0
# 1    2017-09-28  941.36  950.6900  940.55  949.50   959648.0          0.0
# 2    2017-09-27  927.74  949.9000  927.74  944.49  2202959.0          0.0
# 3    2017-09-26  923.72  930.8200  921.14  924.86  1652848.0          0.0
# 4    2017-09-25  925.45  926.4000  909.70  920.97  1822881.0          0.0
# ..          ...     ...       ...     ...     ...        ...          ...
# 246  2016-10-07  779.66  779.6600  770.75  775.08   933158.0          0.0
# 247  2016-10-06  779.00  780.4800  775.54  776.86  1070692.0          0.0
# 248  2016-10-05  779.31  782.0700  775.65  776.47  1461151.0          0.0
# 249  2016-10-04  776.03  778.7100  772.89  776.43  1201350.0          0.0
# 250  2016-10-03  774.25  776.0650  769.50  772.56  1278821.0          0.0
#
#      Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# ...

# %%
#for i, stock in enumerate(stocks):
#   	url = f”https://www.quandl.com/api/v3/datasets/WIKI/{stock}.json?start_date=2016-10-01&end_date=2017-10-01&api_key={api_key}”
#    	response = request.get(url).json()
# 	data = response['dataset']['data']
#    	if i == 0:
#    		c = response['dataset']['column_headers']
#    		c.append("ticker")
# 		final_df = pd.DataFrame(data, columns=c)
# 	else:
# 		temp_df = pd.DataFrame(data, columns=c)
# 		final_df.append(temp_df)
# final_df
