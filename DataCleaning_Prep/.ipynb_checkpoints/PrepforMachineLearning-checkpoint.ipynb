# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
GDP_df = pd.read_csv("GDP.csv")

# %%
GDP_df.rename(columns = {'value':'GDP'}, inplace = True)
GDP_df
# Out:
#       Unnamed: 0  series_id country_code  indicator_code     identifier  \
# 0              0      44908           VN              81  VN.081.1.A.01
# 1              1      44908           VN              81  VN.081.1.A.01
# 2              2      44908           VN              81  VN.081.1.A.01
# 3              3      44908           VN              81  VN.081.1.A.01
# 4              4      44908           VN              81  VN.081.1.A.01
# ...          ...        ...          ...             ...            ...
# 2166        2166       1957           AU              81  AU.081.1.A.01
# 2167        2167       1957           AU              81  AU.081.1.A.01
# 2168        2168       1957           AU              81  AU.081.1.A.01
# 2169        2169       1957           AU              81  AU.081.1.A.01
# 2170        2170       1957           AU              81  AU.081.1.A.01
#
#                                             description         units  \
# 0     Vietnam: GDP (USD) [Vietnam: National accounts...  Millions US$
# 1     Vietnam: GDP (USD) [Vietnam: National accounts...  Millions US$
# 2     Vietnam: GDP (USD) [Vietnam: National accounts...  Millions US$
# 3     Vietnam: GDP (USD) [Vietnam: National accounts...  Millions US$
# 4     Vietnam: GDP (USD) [Vietnam: National accounts...  Millions US$
# ...                                                 ...           ...
# 2166  Australia: GDP (USD) [Australia: National acco...  Millions US$
# 2167  Australia: GDP (USD) [Australia: National acco...  Millions US$
# 2168  Australia: GDP (USD) [Australia: National acco...  Millions US$
# 2169  Australia: GDP (USD) [Australia: National acco...  Millions US$
# 2170  Australia: GDP (USD) [Australia: National acco...  Millions US$
#
#      frequency        date       GDP    country
# 0            A  2019-01-01  261921.0    Vietnam
# 1            A  2018-01-01  245214.0    Vietnam
# 2            A  2017-01-01  223780.0    Vietnam
# 3            A  2016-01-01  205276.0    Vietnam
# 4            A  2015-01-01  193241.0    Vietnam
# ...        ...         ...       ...        ...
# 2166         A  1964-01-01   23764.0  Australia
# 2167         A  1963-01-01   21507.0  Australia
# 2168         A  1962-01-01   19893.0  Australia
# 2169         A  1961-01-01   19653.0  Australia
# 2170         A  1960-01-01   18578.0  Australia
#
# [2171 rows x 11 columns]

# %%
UR_df = pd.read_csv("Unemployment_Rate.csv")

# %%
UR_df.rename(columns = {'value':'UnemploymentRate'}, inplace = True)
UR_df
# Out:
#       Unnamed: 0  series_id country_code  indicator_code   identifier  \
# 0              0      45044           VN             200  VN.200.A.01
# 1              1      45044           VN             200  VN.200.A.01
# 2              2      45044           VN             200  VN.200.A.01
# 3              3      45044           VN             200  VN.200.A.01
# 4              4      45044           VN             200  VN.200.A.01
# ...          ...        ...          ...             ...          ...
# 2023        2023       2168           AU             200  AU.200.A.01
# 2024        2024       2168           AU             200  AU.200.A.01
# 2025        2025       2168           AU             200  AU.200.A.01
# 2026        2026       2168           AU             200  AU.200.A.01
# 2027        2027       2168           AU             200  AU.200.A.01
#
#                                             description units frequency  \
# 0     Vietnam: Unemployment Rate [Vietnam: National ...     %         A
# 1     Vietnam: Unemployment Rate [Vietnam: National ...     %         A
# 2     Vietnam: Unemployment Rate [Vietnam: National ...     %         A
# 3     Vietnam: Unemployment Rate [Vietnam: National ...     %         A
# 4     Vietnam: Unemployment Rate [Vietnam: National ...     %         A
# ...                                                 ...   ...       ...
# 2023  Australia: Unemployment Rate [Australia: Natio...     %         A
# 2024  Australia: Unemployment Rate [Australia: Natio...     %         A
# 2025  Australia: Unemployment Rate [Australia: Natio...     %         A
# 2026  Australia: Unemployment Rate [Australia: Natio...     %         A
# 2027  Australia: Unemployment Rate [Australia: Natio...     %         A
#
#             date  UnemploymentRate    country
# 0     2019-01-01               2.0    Vietnam
# 1     2018-01-01               1.2    Vietnam
# 2     2017-01-01               1.9    Vietnam
# 3     2016-01-01               1.8    Vietnam
# 4     2015-01-01               1.8    Vietnam
# ...          ...               ...        ...
# 2023  1983-01-01              10.0  Australia
# 2024  1982-01-01               7.2  Australia
# 2025  1981-01-01               5.8  Australia
# 2026  1980-01-01               6.1  Australia
# 2027  1979-01-01               6.3  Australia
#
# [2028 rows x 11 columns]

# %%
IR_df = pd.read_csv("Inflation_Rate.csv")

# %%
IR_df.rename(columns = {'value':'InflationRate'}, inplace = True)
IR_df
# Out:
#       Unnamed: 0  series_id country_code  indicator_code   identifier  \
# 0              0      44971           VN             119  VN.119.A.01
# 1              1      44971           VN             119  VN.119.A.01
# 2              2      44971           VN             119  VN.119.A.01
# 3              3      44971           VN             119  VN.119.A.01
# 4              4      44971           VN             119  VN.119.A.01
# ...          ...        ...          ...             ...          ...
# 2141        2141       2051           AU             119  AU.119.A.01
# 2142        2142       2051           AU             119  AU.119.A.01
# 2143        2143       2051           AU             119  AU.119.A.01
# 2144        2144       2051           AU             119  AU.119.A.01
# 2145        2145       2051           AU             119  AU.119.A.01
#
#                                             description units frequency  \
# 0     Vietnam: Inflation Rate [Vietnam: Consumer pri...     %         A
# 1     Vietnam: Inflation Rate [Vietnam: Consumer pri...     %         A
# 2     Vietnam: Inflation Rate [Vietnam: Consumer pri...     %         A
# 3     Vietnam: Inflation Rate [Vietnam: Consumer pri...     %         A
# 4     Vietnam: Inflation Rate [Vietnam: Consumer pri...     %         A
# ...                                                 ...   ...       ...
# 2141  Australia: Inflation Rate [Australia: Consumer...     %         A
# 2142  Australia: Inflation Rate [Australia: Consumer...     %         A
# 2143  Australia: Inflation Rate [Australia: Consumer...     %         A
# 2144  Australia: Inflation Rate [Australia: Consumer...     %         A
# 2145  Australia: Inflation Rate [Australia: Consumer...     %         A
#
#             date  InflationRate    country
# 0     2019-01-01       2.795820    Vietnam
# 1     2018-01-01       3.539569    Vietnam
# 2     2017-01-01       3.520312    Vietnam
# 3     2016-01-01       2.668204    Vietnam
# 4     2015-01-01       0.631215    Vietnam
# ...          ...            ...        ...
# 2141  1965-01-01       3.405568  Australia
# 2142  1964-01-01       2.866352  Australia
# 2143  1963-01-01       0.640913  Australia
# 2144  1962-01-01      -0.319433  Australia
# 2145  1961-01-01       2.287556  Australia
#
# [2146 rows x 11 columns]

# %%
IntR_df = pd.read_csv("InterestRate.csv")

# %%
IntR_df.rename(columns = {'value':'InterestRate'}, inplace = True)
IntR_df
# Out:
#       Unnamed: 0  series_id country_code  indicator_code   identifier  \
# 0              0      44980           VN             124  VN.124.A.01
# 1              1      44980           VN             124  VN.124.A.01
# 2              2      44980           VN             124  VN.124.A.01
# 3              3      44980           VN             124  VN.124.A.01
# 4              4      44980           VN             124  VN.124.A.01
# ...          ...        ...          ...             ...          ...
# 2392        2392       2066           AU             124  AU.124.A.01
# 2393        2393       2066           AU             124  AU.124.A.01
# 2394        2394       2066           AU             124  AU.124.A.01
# 2395        2395       2066           AU             124  AU.124.A.01
# 2396        2396       2066           AU             124  AU.124.A.01
#
#                                             description units frequency  \
# 0     Vietnam: Interest Rate [Vietnam: Interest rate...   %pa         A
# 1     Vietnam: Interest Rate [Vietnam: Interest rate...   %pa         A
# 2     Vietnam: Interest Rate [Vietnam: Interest rate...   %pa         A
# 3     Vietnam: Interest Rate [Vietnam: Interest rate...   %pa         A
# 4     Vietnam: Interest Rate [Vietnam: Interest rate...   %pa         A
# ...                                                 ...   ...       ...
# 2392  Australia: Interest Rate [Australia: Interest ...   %pa         A
# 2393  Australia: Interest Rate [Australia: Interest ...   %pa         A
# 2394  Australia: Interest Rate [Australia: Interest ...   %pa         A
# 2395  Australia: Interest Rate [Australia: Interest ...   %pa         A
# 2396  Australia: Interest Rate [Australia: Interest ...   %pa         A
#
#             date  InterestRate    country
# 0     2019-01-01           5.8    Vietnam
# 1     2018-01-01           3.8    Vietnam
# 2     2017-01-01           2.9    Vietnam
# 3     2016-01-01           5.8    Vietnam
# 4     2015-01-01           7.3    Vietnam
# ...          ...           ...        ...
# 2392  1965-01-01           2.3  Australia
# 2393  1964-01-01           1.7  Australia
# 2394  1963-01-01           3.3  Australia
# 2395  1962-01-01           5.6  Australia
# 2396  1961-01-01           2.2  Australia
#
# [2397 rows x 11 columns]

# %%
SM_df = pd.read_csv("Stock_Market.csv")

# %%
SM_df.rename(columns = {'value':'StockMarket'}, inplace = True)
SM_df.dropna()
# Out:
#       Unnamed: 0  series_id country_code  indicator_code   identifier  \
# 236          236      43946           US             191  US.191.M.01
# 237          237      43946           US             191  US.191.M.01
# 238          238      43946           US             191  US.191.M.01
# 239          239      43946           US             191  US.191.M.01
# 240          240      43946           US             191  US.191.M.01
# ...          ...        ...          ...             ...          ...
# 9995        9995      26804           MX             191  MX.191.D.01
# 9996        9996      26804           MX             191  MX.191.D.01
# 9997        9997      26804           MX             191  MX.191.D.01
# 9998        9998      26804           MX             191  MX.191.D.01
# 9999        9999      26804           MX             191  MX.191.D.01
#
#                                             description         units  \
# 236   United States: Stock Market [US: NYSE Common S...  31Dec02=5000
# 237   United States: Stock Market [US: NYSE Common S...  31Dec02=5000
# 238   United States: Stock Market [US: NYSE Common S...  31Dec02=5000
# 239   United States: Stock Market [US: NYSE Common S...  31Dec02=5000
# 240   United States: Stock Market [US: NYSE Common S...  31Dec02=5000
# ...                                                 ...           ...
# 9995  Mexico: Stock Market [MX: Mexican Stock Market...  Oct1978=0.78
# 9996  Mexico: Stock Market [MX: Mexican Stock Market...  Oct1978=0.78
# 9997  Mexico: Stock Market [MX: Mexican Stock Market...  Oct1978=0.78
# 9998  Mexico: Stock Market [MX: Mexican Stock Market...  Oct1978=0.78
# 9999  Mexico: Stock Market [MX: Mexican Stock Market...  Oct1978=0.78
#
#      frequency        date  StockMarket        country
# 236          M  2020-06-01     11893.78  United States
# 237          M  2020-05-01     11802.95  United States
# 238          M  2020-04-01     11372.34  United States
# 239          M  2020-03-01     10301.87  United States
# 240          M  2020-02-01     12380.97  United States
# ...        ...         ...          ...            ...
# 9995         D  2011-09-23     32588.43         Mexico
# 9996         D  2011-09-22     32381.06         Mexico
# 9997         D  2011-09-21     34019.22         Mexico
# 9998         D  2011-09-20     34337.97         Mexico
# 9999         D  2011-09-19     35076.96         Mexico
#
# [9417 rows x 11 columns]

# %%
GR_df = pd.read_csv("GoldReserve.csv")

# %%
GR_df.rename(columns = {'value':'GoldReserve'}, inplace = True)
GR_df
# Out:
#       Unnamed: 0  series_id country_code  indicator_code   identifier  \
# 0              0      44940           VN              98  VN.098.M.01
# 1              1      44940           VN              98  VN.098.M.01
# 2              2      44940           VN              98  VN.098.M.01
# 3              3      44940           VN              98  VN.098.M.01
# 4              4      44940           VN              98  VN.098.M.01
# ...          ...        ...          ...             ...          ...
# 9995        9995      29395           NZ              98  NZ.098.M.01
# 9996        9996      29395           NZ              98  NZ.098.M.01
# 9997        9997      29395           NZ              98  NZ.098.M.01
# 9998        9998      29395           NZ              98  NZ.098.M.01
# 9999        9999      29395           NZ              98  NZ.098.M.01
#
#                                             description         units  \
# 0     Vietnam: Gold Reserves [Official Reserve Asset...  USD millions
# 1     Vietnam: Gold Reserves [Official Reserve Asset...  USD millions
# 2     Vietnam: Gold Reserves [Official Reserve Asset...  USD millions
# 3     Vietnam: Gold Reserves [Official Reserve Asset...  USD millions
# 4     Vietnam: Gold Reserves [Official Reserve Asset...  USD millions
# ...                                                 ...           ...
# 9995  New Zealand: Gold Reserves [New Zealand: Inter...  Millions USD
# 9996  New Zealand: Gold Reserves [New Zealand: Inter...  Millions USD
# 9997  New Zealand: Gold Reserves [New Zealand: Inter...  Millions USD
# 9998  New Zealand: Gold Reserves [New Zealand: Inter...  Millions USD
# 9999  New Zealand: Gold Reserves [New Zealand: Inter...  Millions USD
#
#      frequency        date  GoldReserve      country
# 0            M  2020-05-01          0.0      Vietnam
# 1            M  2020-04-01          0.0      Vietnam
# 2            M  2020-03-01          0.0      Vietnam
# 3            M  2020-02-01          0.0      Vietnam
# 4            M  2020-01-01          0.0      Vietnam
# ...        ...         ...          ...          ...
# 9995         M  1984-02-01          1.0  New Zealand
# 9996         M  1984-01-01          1.0  New Zealand
# 9997         M  1983-12-01          1.0  New Zealand
# 9998         M  1983-11-01          1.0  New Zealand
# 9999         M  1983-10-01          1.0  New Zealand
#
# [10000 rows x 11 columns]

# %%
COR_df = pd.read_csv("Crude_Oil_Reserve.csv")

# %%
COR_df.rename(columns = {'value':'CrudeOilReserve'}, inplace = True)
COR_df
# Out:
#       Unnamed: 0  series_id country_code  indicator_code   identifier  \
# 0              0      44862           VN              50  VN.050.A.01
# 1              1      44862           VN              50  VN.050.A.01
# 2              2      44862           VN              50  VN.050.A.01
# 3              3      44862           VN              50  VN.050.A.01
# 4              4      44862           VN              50  VN.050.A.01
# ...          ...        ...          ...             ...          ...
# 1546        1546       1900           AU              50  AU.050.A.01
# 1547        1547       1900           AU              50  AU.050.A.01
# 1548        1548       1900           AU              50  AU.050.A.01
# 1549        1549       1900           AU              50  AU.050.A.01
# 1550        1550       1900           AU              50  AU.050.A.01
#
#                                             description       units frequency  \
# 0     Vietnam: Crude Oil Stock Change [WW: Crude Oil...  bln barrel         A
# 1     Vietnam: Crude Oil Stock Change [WW: Crude Oil...  bln barrel         A
# 2     Vietnam: Crude Oil Stock Change [WW: Crude Oil...  bln barrel         A
# 3     Vietnam: Crude Oil Stock Change [WW: Crude Oil...  bln barrel         A
# 4     Vietnam: Crude Oil Stock Change [WW: Crude Oil...  bln barrel         A
# ...                                                 ...         ...       ...
# 1546  Australia: Crude Oil Stock Change [WW: Crude O...  bln barrel         A
# 1547  Australia: Crude Oil Stock Change [WW: Crude O...  bln barrel         A
# 1548  Australia: Crude Oil Stock Change [WW: Crude O...  bln barrel         A
# 1549  Australia: Crude Oil Stock Change [WW: Crude O...  bln barrel         A
# 1550  Australia: Crude Oil Stock Change [WW: Crude O...  bln barrel         A
#
#             date  CrudeOilReserve    country
# 0     2019-01-01              0.0    Vietnam
# 1     2018-01-01              0.0    Vietnam
# 2     2017-01-01              0.0    Vietnam
# 3     2016-01-01              0.0    Vietnam
# 4     2015-01-01              0.0    Vietnam
# ...          ...              ...        ...
# 1546  1985-01-01             -0.2  Australia
# 1547  1984-01-01              0.0  Australia
# 1548  1983-01-01             -0.1  Australia
# 1549  1982-01-01             -0.7  Australia
# 1550  1981-01-01              0.3  Australia
#
# [1551 rows x 11 columns]

# %%
#result = pd.merge(GDP_df['GDP'], UR_df['UnemploymentRate'], on='country')
result = GDP_df.merge(UR_df, on=['country','date'])[['country','date','GDP','UnemploymentRate']]

# %%
result = result.merge(IR_df, on=['country','date'])[['country','date','GDP','UnemploymentRate','InflationRate']]

# %%
result = result.merge(IntR_df, on=['country','date'])[['country','date','GDP','UnemploymentRate','InflationRate','InterestRate']]

# %%
result = result.merge(SM_df, on=['country','date'])[['country','date','GDP','UnemploymentRate','InflationRate','InterestRate','StockMarket']]

# %%
result = result.merge(GR_df, on=['country','date'])[['country','date','GDP','UnemploymentRate','InflationRate','InterestRate','GoldReserve']]

# %%
result = result.merge(COR_df, on=['country','date'])[['country','date','GDP','UnemploymentRate','InflationRate','InterestRate','CrudeOilReserve']]

# %%
result
# Out:
#        country        date       GDP  UnemploymentRate  InflationRate  \
# 0      Vietnam  2019-01-01  261921.0               2.0       2.795820
# 1      Vietnam  2018-01-01  245214.0               1.2       3.539569
# 2      Vietnam  2017-01-01  223780.0               1.9       3.520312
# 3      Vietnam  2016-01-01  205276.0               1.8       2.668204
# 4      Vietnam  2015-01-01  193241.0               1.8       0.631215
# ..         ...         ...       ...               ...            ...
# 847  Australia  1985-01-01  180235.0               8.3       6.734687
# 848  Australia  1984-01-01  193242.0               9.0       3.960407
# 849  Australia  1983-01-01  177030.0              10.0      10.038913
# 850  Australia  1982-01-01  193770.0               7.2      11.351826
# 851  Australia  1981-01-01  176642.0               5.8       9.487679
#
#      InterestRate  CrudeOilReserve
# 0             5.8              0.0
# 1             3.8              0.0
# 2             2.9              0.0
# 3             5.8              0.0
# 4             7.3              0.0
# ..            ...              ...
# 847           7.4             -0.2
# 848           3.4              0.0
# 849           2.1             -0.1
# 850           1.4             -0.7
# 851           2.1              0.3
#
# [852 rows x 7 columns]

# %%
result.describe()
# Out:
#                 GDP  UnemploymentRate  InflationRate  InterestRate  \
# count  8.520000e+02        852.000000     852.000000    852.000000
# mean   1.244710e+06          7.083592      20.109343      6.962641
# std    2.758897e+06          4.659217     281.707453     12.118218
# min    7.870000e+00          0.100000      -4.863332    -45.600000
# 25%    9.271475e+04          3.900000       1.897336      2.400000
# 50%    2.987630e+05          6.100000       3.517596      4.500000
# 75%    1.141067e+06          9.100000       6.746693      7.800000
# max    2.142770e+07         33.300000    7481.663611     95.220000
#
#        CrudeOilReserve
# count       852.000000
# mean         -0.036189
# std           8.722719
# min        -107.400000
# 25%          -0.005000
# 50%           0.000000
# 75%           0.000000
# max         175.163000

# %%
result.hist(figsize=(10,14),grid=True)
plt.show()
