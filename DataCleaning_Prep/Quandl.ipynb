# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import json
import pandas as pd
from config import api_key

# %%
GDP ='45843'
GDPInt = int(GDP)
GDP1 = '718'

# %%
#No Filter
url = f"https://www.quandl.com/api/v3/datatables/EDIA/ECD?api_key={api_key}"
print(url)
# Out:
# https://www.quandl.com/api/v3/datatables/EDIA/ECD?api_key=fxZzuDxTUwi4x7ZqE2zY

# %%
#With Date Filter
url = url = f"https://www.quandl.com/api/v3/datatables/EDIA/ECD?date=2016-07-01&api_key={api_key}"
print(url)
# Out:
# https://www.quandl.com/api/v3/datatables/EDIA/ECD?date=2016-07-01&api_key=fxZzuDxTUwi4x7ZqE2zY

# %%
#With Series Id Filter
url = url = f"https://www.quandl.com/api/v3/datatables/EDIA/ECD?series_id={GDPInt}&api_key={api_key}"
print(url)
# Out:
# https://www.quandl.com/api/v3/datatables/EDIA/ECD?series_id=45843&api_key=fxZzuDxTUwi4x7ZqE2zY

# %%
#With Series Id and Date Filter
url = url = f"https://www.quandl.com/api/v3/datatables/EDIA/ECD?date=2016-07-01&series_id={GDPInt}&api_key={api_key}"
print(url)
# Out:
# https://www.quandl.com/api/v3/datatables/EDIA/ECD?date=2016-07-01&series_id=45843&api_key=fxZzuDxTUwi4x7ZqE2zY

# %%
#With more than one Series Id '734', '43290'
url = url = f"https://www.quandl.com/api/v3/datatables/EDIA/ECD?series_id=734%2C43290&api_key={api_key}"
print(url)
# Out:
# https://www.quandl.com/api/v3/datatables/EDIA/ECD?series_id=734%2C43290&api_key=fxZzuDxTUwi4x7ZqE2zY

# %%
# •	GDP growth rate  
#    734,43290,89,1143,288,1560,874,1320,689,2297,1994,1771,2545,4827,3091,3752,6115,5856,2900,6327,4132,5640,4615
# 5328,4409,5056,3492,3954,6995,8903,39941,7921,8207,8505,9398,9915,7242,10141,10441,15700,11217,10956
    
# •	Unemployment rate
# •	Labor force participation rate
# •	Ease of doing business
# •	Inflation rate
# •	Bank lending rate
# •	Consumer Confidence
# •	Corporate Tax Rate
# •	Gold Reserve
# •	Population
# •	GDP Deflator
# •	Corruption Index

# %%
list_GDP = ["734","43290","89","1143","288","1560","874","1320","689","2297","1994","1771","2545","4827","3091","3752","6115","5856","2900","6327","4132","5640","4615"
,"5328","4409","5056","3492","3954","6995","8903","39941","7921","8207","8505","9398","9915","7242","10141","10441","15700","11217","10956"]

# %%
NewList = '%2C'.join(list_GDP)
NewList
# Out:
# '734%2C43290%2C89%2C1143%2C288%2C1560%2C874%2C1320%2C689%2C2297%2C1994%2C1771%2C2545%2C4827%2C3091%2C3752%2C6115%2C5856%2C2900%2C6327%2C4132%2C5640%2C4615%2C5328%2C4409%2C5056%2C3492%2C3954%2C6995%2C8903%2C39941%2C7921%2C8207%2C8505%2C9398%2C9915%2C7242%2C10141%2C10441%2C15700%2C11217%2C10956'

# %%
#With passing the list of GDP
url = url = f"https://www.quandl.com/api/v3/datatables/EDIA/ECD?series_id={NewList}&api_key={api_key}"
print(url)
# Out:
# https://www.quandl.com/api/v3/datatables/EDIA/ECD?series_id=734%2C43290%2C89%2C1143%2C288%2C1560%2C874%2C1320%2C689%2C2297%2C1994%2C1771%2C2545%2C4827%2C3091%2C3752%2C6115%2C5856%2C2900%2C6327%2C4132%2C5640%2C4615%2C5328%2C4409%2C5056%2C3492%2C3954%2C6995%2C8903%2C39941%2C7921%2C8207%2C8505%2C9398%2C9915%2C7242%2C10141%2C10441%2C15700%2C11217%2C10956&api_key=fxZzuDxTUwi4x7ZqE2zY

# %%
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "datatable": {
#         "columns": [
#             {
#                 "name": "series_id",
#                 "type": "Integer"
#             },
#             {
#                 "name": "country_code",
#                 "type": "text"
#             },
#             {
#                 "name": "indicator_code",
#                 "type": "text"
#             },
#             {
#                 "name": "identifier",
#                 "type": "text"
#             },
#             {
#                 "name": "description",
#                 "type": "text"
#             },
#             {
#                 "name": "units",
#                 "type": "text"
#             },
#             {
#                 "name": "frequency",
#                 "type": "text"
#             },
#             {
#                 "name": "date",
#                 "type": "Date"
#             },
#             {
#                 "name": "value",
#                 "type": "double"
#             }
# ...

# %%
col = []
for c in response['datatable']['columns']:
    col.append(c['name'])

# %%
df = pd.DataFrame(response['datatable']['data'],columns=col)

df.tail()
# Out:
#       series_id country_code indicator_code   identifier  \
# 1990         89           AF            095  AF.095.A.02
# 1991         89           AF            095  AF.095.A.02
# 1992         89           AF            095  AF.095.A.02
# 1993         89           AF            095  AF.095.A.02
# 1994         89           AF            095  AF.095.A.02
#
#                                             description units frequency  \
# 1990  Afghanistan: GDP Growth Rate [Afghanistan: Nat...     %         A
# 1991  Afghanistan: GDP Growth Rate [Afghanistan: Nat...     %         A
# 1992  Afghanistan: GDP Growth Rate [Afghanistan: Nat...     %         A
# 1993  Afghanistan: GDP Growth Rate [Afghanistan: Nat...     %         A
# 1994  Afghanistan: GDP Growth Rate [Afghanistan: Nat...     %         A
#
#             date      value
# 1990  1965-01-01  25.833333
# 1991  1964-01-01   6.508876
# 1992  1963-01-01  37.398374
# 1993  1962-01-01  -0.404858
# 1994  1961-01-01   2.066116

# %%
df.shape
# Out:
# (1995, 9)

# %%
df['country'] = df['description'].apply(lambda  x : x.split(":")[0]  )
df
# Out:
#       series_id country_code indicator_code   identifier  \
# 0         43290           AE            095  AE.095.A.01
# 1         43290           AE            095  AE.095.A.01
# 2         43290           AE            095  AE.095.A.01
# 3         43290           AE            095  AE.095.A.01
# 4         43290           AE            095  AE.095.A.01
# ...         ...          ...            ...          ...
# 1990         89           AF            095  AF.095.A.02
# 1991         89           AF            095  AF.095.A.02
# 1992         89           AF            095  AF.095.A.02
# 1993         89           AF            095  AF.095.A.02
# 1994         89           AF            095  AF.095.A.02
#
#                                             description units frequency  \
# 0     United Arab Emirates: GDP Growth Rate [United ...     %         A
# 1     United Arab Emirates: GDP Growth Rate [United ...     %         A
# ...

# %%
df.country.unique()
# Out:
# array(['United Arab Emirates', 'Switzerland', 'Germany', 'Djibouti',
#        'Denmark', 'Czech Republic', 'Cyprus', 'Cuba', 'Costa Rica',
#        'Congo', 'Colombia', 'China', 'Chile', 'Cape Verde', 'Canada',
#        'Burundi', 'Burkina Faso', 'Bulgaria', 'Brunei', 'Brazil',
#        'Botswana', 'Bosnia and Herzegovina', 'Bolivia', 'Bhutan', 'Benin',
#        'Belize', 'Belgium', 'Belarus', 'Bangladesh', 'Bahrain',
#        'Azerbaijan', 'Austria', 'Australia', 'Aruba', 'Armenia',
#        'Argentina', 'Antigua and Barbuda', 'Angola', 'Andorra',
#        'American Samoa', 'Albania', 'Afghanistan'], dtype=object)

# %%
Sep19_df = df[df.date == '2019-01-01']
Sep19_df.shape
# Out:
# (38, 10)
